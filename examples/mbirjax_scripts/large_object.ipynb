# %% [markdown]
# **MBIRJAX: Large Object Demo**
#
# See the [MBIRJAX documentation](https://mbirjax.readthedocs.io/en/latest/) for an overview and details.
#
# This script demonstrates how to improve the reconstruction when the object does not project completely inside the detector.  For simplicity, we show this only for parallel beam, but the same steps apply for cone beam.
#
# See [demo_1_shepp_logan.py](https://colab.research.google.com/drive/1zG_H6CDjuQxeMRQHan3XEyX2YVKcSSNC) for the basic steps of synthetic sinogram generation and reconstruction.
#
# Select a GPU as runtime type for best performance.

# %%
import numpy as np
import time
import pprint
import jax.numpy as jnp
import mbirjax

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"

# %% [markdown]
# **Set the geometry parameters**

# %%
# Set parameters for the problem size - you can vary these, but if you make num_det_rows very small relative to
# channels, then the generated phantom may not have an interior.
num_views = 120
num_det_rows = 80
num_det_channels = 100

start_angle = - np.pi / 2
end_angle = np.pi / 2

# %% [markdown]
# **Data generation:** For demo purposes, we create a phantom and then project it to create a sinogram.
#
# The default recon shape for parallel beam is
#
# (rows, columns, slices) = (num_det_channels, num_det_channels, num_det_rows),
#
# where we assume that the recon voxels are cubes and have the same size as the detector elements.
# Here we generate a phantom that is bigger than the detector to show how to deal with this case.
#
#
# Note:  the sliders on the viewer won't work in notebook form.  For that you'll need to run the python code with an interactive matplotlib backend, typcially using the command line or a development environment like Spyder or Pycharm to invoke python.

# %%
# Initialize sinogram
sinogram_shape = (num_views, num_det_rows, num_det_channels)
angles = jnp.linspace(start_angle, end_angle, num_views, endpoint=False)

ct_model_for_generation = mbirjax.ParallelBeamModel(sinogram_shape, angles)

# Generate large 3D Shepp Logan phantom
print('Creating phantom that projects partially outside the detector')
phantom_row_scale = 1.0
phantom_col_scale = 1.75
phantom_rows = int(num_det_channels * phantom_row_scale)
phantom_cols = int(num_det_channels * phantom_col_scale)
phantom_slices = num_det_rows
phantom_shape = (phantom_rows, phantom_cols, phantom_slices)
phantom = mbirjax.generate_3d_shepp_logan_low_dynamic_range(phantom_shape)

# Generate synthetic sinogram data
print('Creating sinogram')
ct_model_for_generation.set_params(recon_shape=phantom_shape)
sinogram = ct_model_for_generation.forward_project(phantom)
sinogram = np.asarray(sinogram)

# View sinogram
mbirjax.slice_viewer(sinogram, title='Original sinogram\nChange view to see projections in and outside detector',
                 slice_axis=0, slice_label='View')
# Out:
# Creating phantom that projects partially outside the detector
# Creating sinogram

# %% [markdown]
# **Do a baseline reconstruction**
#
# First we do a reconstruction with the default settings.  This will have significant artifacts because some of the information in the sinogram comes from voxels that are projected to the detector on only some of the views.  In the default reconstruction, all of the voxels in the reconstruction project to the detector in all of the views, so there is only way to account for these partially projected voxels leads to a corrupted reconstruciton.

# %%
# Initialize model for default reconstruction.
weights = None
ct_model_for_recon = mbirjax.ParallelBeamModel(sinogram_shape, angles)

# Print model parameters
ct_model_for_recon.print_params()

# Default VCD reconstruction
print('Starting default recon - will have significant artifacts because of the missing projections.\n')
time0 = time.time()
recon, recon_params = ct_model_for_recon.recon(sinogram, weights=weights)
recon.block_until_ready()
elapsed = time.time() - time0

# Print out parameters used in recon
if isinstance(recon_params, dict):
    pprint.pprint(recon_params, compact=True)
else:
    pprint.pprint(recon_params._asdict(), compact=True)
print('Elapsed time for recon is {:.3f} seconds'.format(elapsed))
# Out:
# GPU used for: full
# Estimated GPU memory required = 1.281 GB, available = 91.115 GB
# Estimated CPU memory required = 0.013 GB, available = 1463.766 GB
# Starting direct recon for initial reconstruction
# ----
# geometry_type = <class 'mbirjax.parallel_beam.ParallelBeamModel'>
# file_format = 1.0
# sinogram_shape = (120, 80, 100)
# delta_det_channel = 1.0
# delta_det_row = 1.0
# det_row_offset = 0.0
# det_channel_offset = 0.0
# sigma_y = 1.0
# recon_shape = (100, 100, 80)
# delta_voxel = 1.0
# sigma_x = 1.0
# sigma_prox = 1.0
# p = 2.0
# q = 1.2
# T = 1.0
# qggmrf_nbr_wts = [1.0, 1.0, 1.0]
# auto_regularize_flag = True
# positivity_flag = False
# snr_db = 30.0
# sharpness = 1.0
# granularity = [1, 2, 4, 8, 16, 32, 64, 128, 256]
# partition_sequence = [0, 2, 4, 6, 7]
# verbose = 1
# use_gpu = automatic
# view_params_name = angles
# ----
# Starting default recon - will have significant artifacts because of the missing projections.
# Initializing error sinogram
# Computing Hessian diagonal
# Starting VCD iterations
#
# After iteration 0 of a max of 15: Pct change=7.1196, Forward loss=6.0703
# Relative step size (alpha)=0.03, Error sino RMSE=3.6284
# Number subsets = 1
#
# After iteration 1 of a max of 15: Pct change=10.8037, Forward loss=5.8899
# Relative step size (alpha)=0.10, Error sino RMSE=3.5206
# Number subsets = 4
#
# After iteration 2 of a max of 15: Pct change=12.5848, Forward loss=5.7815
# Relative step size (alpha)=0.41, Error sino RMSE=3.4558
# Number subsets = 16
#
# After iteration 3 of a max of 15: Pct change=14.1173, Forward loss=5.7284
# Relative step size (alpha)=1.08, Error sino RMSE=3.4241
# Number subsets = 64
#
# After iteration 4 of a max of 15: Pct change=8.3934, Forward loss=5.7118
# Relative step size (alpha)=1.13, Error sino RMSE=3.4142
# Number subsets = 128
#
# After iteration 5 of a max of 15: Pct change=5.5133, Forward loss=5.7035
# Relative step size (alpha)=1.11, Error sino RMSE=3.4092
# Number subsets = 128
#
# After iteration 6 of a max of 15: Pct change=3.9980, Forward loss=5.6980
# Relative step size (alpha)=1.11, Error sino RMSE=3.4059
# Number subsets = 128
#
# After iteration 7 of a max of 15: Pct change=3.1596, Forward loss=5.6940
# Relative step size (alpha)=1.11, Error sino RMSE=3.4035
# Number subsets = 128
#
# After iteration 8 of a max of 15: Pct change=2.5545, Forward loss=5.6910
# Relative step size (alpha)=1.11, Error sino RMSE=3.4017
# Number subsets = 128
#
# After iteration 9 of a max of 15: Pct change=2.0787, Forward loss=5.6886
# Relative step size (alpha)=1.11, Error sino RMSE=3.4003
# Number subsets = 128
#
# After iteration 10 of a max of 15: Pct change=1.6962, Forward loss=5.6868
# Relative step size (alpha)=1.10, Error sino RMSE=3.3992
# Number subsets = 128
#
# After iteration 11 of a max of 15: Pct change=1.4744, Forward loss=5.6852
# Relative step size (alpha)=1.10, Error sino RMSE=3.3983
# Number subsets = 128
#
# After iteration 12 of a max of 15: Pct change=1.2542, Forward loss=5.6839
# Relative step size (alpha)=1.10, Error sino RMSE=3.3975
# Number subsets = 128
#
# After iteration 13 of a max of 15: Pct change=1.1123, Forward loss=5.6828
# Relative step size (alpha)=1.10, Error sino RMSE=3.3968
# Number subsets = 128
#
# After iteration 14 of a max of 15: Pct change=0.9533, Forward loss=5.6818
# Relative step size (alpha)=1.10, Error sino RMSE=3.3963
# Number subsets = 128
# Logs written to /home/zhengtan/repos/scico/examples/mbirjax_scripts/logs/recon.log
# {'model_params': {'T': Param(val=1.0, recompile_flag=False),
#                   'angles': Param(val=[-1.5707964e+00 -1.5446163e+00 -1.5184366e+00 -1.4922565e+00
#  -1.4660765e+00 -1.4398967e+00 -1.4137167e+00 -1.3875369e+00
#  -1.3613569e+00 -1.3351769e+00 -1.3089970e+00 -1.2828170e+00
#  -1.2566370e+00 -1.2304572e+00 -1.2042772e+00 -1.1780972e+00
#  -1.1519173e+00 -1.1257374e+00 -1.0995575e+00 -1.0733775e+00
#  -1.0471975e+00 -1.0210177e+00 -9.9483764e-01 -9.6865779e-01
#  -9.4247770e-01 -9.1629779e-01 -8.9011782e-01 -8.6393797e-01
#  -8.3775795e-01 -8.1157815e-01 -7.8539813e-01 -7.5921828e-01
#  -7.3303831e-01 -7.0685840e-01 -6.8067831e-01 -6.5449846e-01
#  -6.2831843e-01 -6.0213858e-01 -5.7595861e-01 -5.4977864e-01
#  -5.2359861e-01 -4.9741876e-01 -4.7123879e-01 -4.4505894e-01
#  -4.1887897e-01 -3.9269906e-01 -3.6651915e-01 -3.4033924e-01
#  -3.1415915e-01 -2.8797925e-01 -2.6179934e-01 -2.3561937e-01
#  -2.0943934e-01 -1.8325943e-01 -1.5707952e-01 -1.3089955e-01
#  -1.0471964e-01 -7.8539729e-02 -5.2359819e-02 -2.6179850e-02
#   5.9604645e-08  2.6180089e-02  5.2359998e-02  7.8539968e-02
#   1.0471988e-01  1.3089979e-01  1.5707976e-01  1.8325967e-01
#   2.0943964e-01  2.3561960e-01  2.6179957e-01  2.8797948e-01
#   3.1415939e-01  3.4033930e-01  3.6651927e-01  3.9269924e-01
#   4.1887915e-01  4.4505912e-01  4.7123897e-01  4.9741894e-01
#   5.2359897e-01  5.4977882e-01  5.7595885e-01  6.0213882e-01
#   6.2831867e-01  6.5449870e-01  6.8067849e-01  7.0685852e-01
#   7.3303843e-01  7.5921839e-01  7.8539836e-01  8.1157833e-01
#   8.3775818e-01  8.6393815e-01  8.9011800e-01  9.1629803e-01
#   9.4247806e-01  9.6865791e-01  9.9483788e-01  1.0210178e+00
#   1.0471977e+00  1.0733776e+00  1.0995576e+00  1.1257375e+00
#   1.1519176e+00  1.1780974e+00  1.2042774e+00  1.2304573e+00
#   1.2566372e+00  1.2828171e+00  1.3089972e+00  1.3351771e+00
#   1.3613571e+00  1.3875370e+00  1.4137169e+00  1.4398968e+00
#   1.4660767e+00  1.4922566e+00  1.5184368e+00  1.5446166e+00], recompile_flag=True),
#                   'auto_regularize_flag': Param(val=True, recompile_flag=False),
#                   'delta_det_channel': Param(val=1.0, recompile_flag=True),
#                   'delta_det_row': Param(val=1.0, recompile_flag=True),
#                   'delta_voxel': Param(val=1.0, recompile_flag=True),
#                   'det_channel_offset': Param(val=0.0, recompile_flag=True),
#                   'det_row_offset': Param(val=0.0, recompile_flag=True),
#                   'file_format': Param(val=1.0, recompile_flag=False),
#                   'geometry_type': Param(val=<class 'mbirjax.parallel_beam.ParallelBeamModel'>, recompile_flag=False),
#                   'granularity': Param(val=[1, 2, 4, 8, 16, 32, 64, 128, 256], recompile_flag=False),
#                   'p': Param(val=2.0, recompile_flag=False),
#                   'partition_sequence': Param(val=[0, 2, 4, 6, 7], recompile_flag=False),
#                   'positivity_flag': Param(val=False, recompile_flag=False),
#                   'q': Param(val=1.2, recompile_flag=False),
#                   'qggmrf_nbr_wts': Param(val=[1.0, 1.0, 1.0], recompile_flag=False),
#                   'recon_shape': Param(val=(100, 100, 80), recompile_flag=True),
#                   'sharpness': Param(val=1.0, recompile_flag=False),
#                   'sigma_prox': Param(val=0.071230947971344, recompile_flag=False),
#                   'sigma_x': Param(val=0.071230947971344, recompile_flag=False),
#                   'sigma_y': Param(val=0.5977396965026855, recompile_flag=False),
#                   'sinogram_shape': Param(val=(120, 80, 100), recompile_flag=True),
#                   'snr_db': Param(val=30.0, recompile_flag=False),
#                   'use_gpu': Param(val=automatic, recompile_flag=True),
#                   'verbose': Param(val=1, recompile_flag=False),
#                   'view_params_name': Param(val=angles, recompile_flag=True)},
#  'notes': 'Reconstruction completed: 2025-06-26 14:42:34.041149\n\n',
#  'recon_log': 'GPU used for: full\n'
#               'Estimated GPU memory required = 1.281 GB, available = 91.115 '
#               'GB\n'
#               'Estimated CPU memory required = 0.013 GB, available = 1463.766 '
#               'GB\n'
#               'Starting direct recon for initial reconstruction\n'
#               'Initializing error sinogram\n'
#               'Computing Hessian diagonal\n'
#               'Starting VCD iterations\n'
#               '\n'
#               'After iteration 0 of a max of 15: Pct change=7.1196, Forward '
#               'loss=6.0703\n'
#               'Relative step size (alpha)=0.03, Error sino RMSE=3.6284\n'
#               'Number subsets = 1\n'
#               '\n'
#               'After iteration 1 of a max of 15: Pct change=10.8037, Forward '
#               'loss=5.8899\n'
#               'Relative step size (alpha)=0.10, Error sino RMSE=3.5206\n'
#               'Number subsets = 4\n'
#               '\n'
#               'After iteration 2 of a max of 15: Pct change=12.5848, Forward '
#               'loss=5.7815\n'
#               'Relative step size (alpha)=0.41, Error sino RMSE=3.4558\n'
#               'Number subsets = 16\n'
#               '\n'
#               'After iteration 3 of a max of 15: Pct change=14.1173, Forward '
#               'loss=5.7284\n'
#               'Relative step size (alpha)=1.08, Error sino RMSE=3.4241\n'
#               'Number subsets = 64\n'
#               '\n'
#               'After iteration 4 of a max of 15: Pct change=8.3934, Forward '
#               'loss=5.7118\n'
#               'Relative step size (alpha)=1.13, Error sino RMSE=3.4142\n'
#               'Number subsets = 128\n'
#               '\n'
#               'After iteration 5 of a max of 15: Pct change=5.5133, Forward '
#               'loss=5.7035\n'
#               'Relative step size (alpha)=1.11, Error sino RMSE=3.4092\n'
#               'Number subsets = 128\n'
#               '\n'
#               'After iteration 6 of a max of 15: Pct change=3.9980, Forward '
#               'loss=5.6980\n'
#               'Relative step size (alpha)=1.11, Error sino RMSE=3.4059\n'
#               'Number subsets = 128\n'
#               '\n'
#               'After iteration 7 of a max of 15: Pct change=3.1596, Forward '
#               'loss=5.6940\n'
#               'Relative step size (alpha)=1.11, Error sino RMSE=3.4035\n'
#               'Number subsets = 128\n'
#               '\n'
#               'After iteration 8 of a max of 15: Pct change=2.5545, Forward '
#               'loss=5.6910\n'
#               'Relative step size (alpha)=1.11, Error sino RMSE=3.4017\n'
#               'Number subsets = 128\n'
#               '\n'
#               'After iteration 9 of a max of 15: Pct change=2.0787, Forward '
#               'loss=5.6886\n'
#               'Relative step size (alpha)=1.11, Error sino RMSE=3.4003\n'
#               'Number subsets = 128\n'
#               '\n'
#               'After iteration 10 of a max of 15: Pct change=1.6962, Forward '
#               'loss=5.6868\n'
#               'Relative step size (alpha)=1.10, Error sino RMSE=3.3992\n'
#               'Number subsets = 128\n'
#               '\n'
#               'After iteration 11 of a max of 15: Pct change=1.4744, Forward '
#               'loss=5.6852\n'
#               'Relative step size (alpha)=1.10, Error sino RMSE=3.3983\n'
#               'Number subsets = 128\n'
#               '\n'
#               'After iteration 12 of a max of 15: Pct change=1.2542, Forward '
#               'loss=5.6839\n'
#               'Relative step size (alpha)=1.10, Error sino RMSE=3.3975\n'
#               'Number subsets = 128\n'
#               '\n'
#               'After iteration 13 of a max of 15: Pct change=1.1123, Forward '
#               'loss=5.6828\n'
#               'Relative step size (alpha)=1.10, Error sino RMSE=3.3968\n'
#               'Number subsets = 128\n'
#               '\n'
#               'After iteration 14 of a max of 15: Pct change=0.9533, Forward '
#               'loss=5.6818\n'
#               'Relative step size (alpha)=1.10, Error sino RMSE=3.3963\n'
#               'Number subsets = 128\n'
#               'Logs written to '
#               '/home/zhengtan/repos/scico/examples/mbirjax_scripts/logs/recon.log\n',
#  'recon_params': {'alpha_values': [0.031893059611320496, 0.09985775500535965,
#                                    0.40883979201316833, 1.0776681900024414,
#                                    1.1277132034301758, 1.1147339344024658,
#                                    1.1097017526626587, 1.1091512441635132,
#                                    1.1081711053848267, 1.1056511402130127,
#                                    1.098313331604004, 1.103029489517212,
#                                    1.0983339548110962, 1.099947214126587,
#                                    1.097948431968689],
#                   'fm_rmse': [6.070270538330078, 5.8899078369140625,
#                               5.781497001647949, 5.728382587432861,
#                               5.711790561676025, 5.703474998474121,
#                               5.697968006134033, 5.6940202713012695,
#                               5.690978527069092, 5.688632965087891,
#                               5.686772346496582, 5.685209274291992,
#                               5.683925628662109, 5.682766437530518,
#                               5.681832313537598],
#                   'granularity': [1, 2, 4, 8, 16, 32, 64, 128, 256],
#                   'num_iterations': 15,
#                   'partition_sequence': [0, 2, 4, 6, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#                                          7, 7],
#                   'prior_loss': [0],
#                   'regularization_params': {'sigma_prox': 0.071230947971344,
#                                             'sigma_x': 0.071230947971344,
#                                             'sigma_y': 0.5977396965026855},
#                   'stop_threshold_change_pct': [7.119571417570114,
#                                                 10.803675651550293,
#                                                 12.584847211837769,
#                                                 14.117343723773956,
#                                                 8.393409848213196,
#                                                 5.513295158743858,
#                                                 3.9979837834835052,
#                                                 3.1595613807439804,
#                                                 2.5545040145516396,
#                                                 2.07871925085783,
#                                                 1.6961585730314255,
#                                                 1.4743736945092678,
#                                                 1.2542307376861572,
#                                                 1.112260390073061,
#                                                 0.9533247910439968]}}
# Elapsed time for recon is 13.197 seconds

# %% [markdown]
# **Display the default reconstruction.**

# %%
title = 'Default recon: Phantom (left) vs VCD Recon (right)'
title += '\nAdjust intensity range to [0, 1] to see internal artifacts from projection outside detector.'
title += '\nAdjust intensity range to [1.5, 2] to see outer ring from projection outside detector.'

save_path = './results/recon_default.png'
mbirjax.slice_viewer(phantom, recon, title=title, vmin=0.0, vmax=2.0, save=True, save_path=save_path)

# %% [markdown]
# **Decrease sharpness to reduce artifacts.**
#
# One way to reduce the artifacts seen above is to decrease sharpness, which promotes smoother images.  This does reduce artifacts but also blurs the edges.
#
# Below we show that we can pad the recon to reduce artifacts without blurring the edges.

# %%
# Increased regularization VCD reconstruction
# We can reduce the artifacts by increasing regularization (decreasing sharpness).
sharpness = -1.5
ct_model_for_recon.set_params(sharpness=sharpness)
print('\nStarting recon with reduced sharpness - will have reduced artifacts but blurred edges.\n')
recon_smooth, recon_params_smooth = ct_model_for_recon.recon(sinogram, weights=weights)

# Print out parameters used in recon
if isinstance(recon_params_smooth, dict):
    pprint.pprint(recon_params_smooth, compact=True)
else:
    pprint.pprint(recon_params_smooth._asdict(), compact=True)
# Out:
# GPU used for: full
# Estimated GPU memory required = 1.281 GB, available = 91.115 GB
# Estimated CPU memory required = 0.013 GB, available = 1463.766 GB
# Starting direct recon for initial reconstruction
# Initializing error sinogram
# Computing Hessian diagonal
# Starting VCD iterations
#
# After iteration 0 of a max of 15: Pct change=6.8342, Forward loss=6.0597
# Relative step size (alpha)=0.18, Error sino RMSE=3.6221
# Number subsets = 1
#
# After iteration 1 of a max of 15: Pct change=9.5596, Forward loss=5.8612
# Starting recon with reduced sharpness - will have reduced artifacts but blurred edges.
# Relative step size (alpha)=0.56, Error sino RMSE=3.5035
# Number subsets = 4
#
# After iteration 2 of a max of 15: Pct change=9.3781, Forward loss=5.7834
# Relative step size (alpha)=1.47, Error sino RMSE=3.4570
# Number subsets = 16
#
# After iteration 3 of a max of 15: Pct change=4.1690, Forward loss=5.7644
# Relative step size (alpha)=1.50, Error sino RMSE=3.4456
# Number subsets = 64
#
# After iteration 4 of a max of 15: Pct change=2.0243, Forward loss=5.7576
# Relative step size (alpha)=1.50, Error sino RMSE=3.4415
# Number subsets = 128
#
# After iteration 5 of a max of 15: Pct change=1.1462, Forward loss=5.7539
# Relative step size (alpha)=1.50, Error sino RMSE=3.4393
# Number subsets = 128
#
# After iteration 6 of a max of 15: Pct change=0.7416, Forward loss=5.7519
# Relative step size (alpha)=1.50, Error sino RMSE=3.4382
# Number subsets = 128
#
# After iteration 7 of a max of 15: Pct change=0.5177, Forward loss=5.7505
# Relative step size (alpha)=1.50, Error sino RMSE=3.4373
# Number subsets = 128
#
# After iteration 8 of a max of 15: Pct change=0.3786, Forward loss=5.7496
# Relative step size (alpha)=1.50, Error sino RMSE=3.4367
# Number subsets = 128
#
# After iteration 9 of a max of 15: Pct change=0.2872, Forward loss=5.7489
# Relative step size (alpha)=1.50, Error sino RMSE=3.4363
# Number subsets = 128
#
# After iteration 10 of a max of 15: Pct change=0.2261, Forward loss=5.7483
# Relative step size (alpha)=1.50, Error sino RMSE=3.4360
# Number subsets = 128
#
# After iteration 11 of a max of 15: Pct change=0.1815, Forward loss=5.7479
# Relative step size (alpha)=1.50, Error sino RMSE=3.4358
# Number subsets = 128
# Change threshold stopping condition reached
# Logs written to /home/zhengtan/repos/scico/examples/mbirjax_scripts/logs/recon.log
# {'model_params': {'T': Param(val=1.0, recompile_flag=False),
#                   'angles': Param(val=[-1.5707964e+00 -1.5446163e+00 -1.5184366e+00 -1.4922565e+00
#  -1.4660765e+00 -1.4398967e+00 -1.4137167e+00 -1.3875369e+00
#  -1.3613569e+00 -1.3351769e+00 -1.3089970e+00 -1.2828170e+00
#  -1.2566370e+00 -1.2304572e+00 -1.2042772e+00 -1.1780972e+00
#  -1.1519173e+00 -1.1257374e+00 -1.0995575e+00 -1.0733775e+00
#  -1.0471975e+00 -1.0210177e+00 -9.9483764e-01 -9.6865779e-01
#  -9.4247770e-01 -9.1629779e-01 -8.9011782e-01 -8.6393797e-01
#  -8.3775795e-01 -8.1157815e-01 -7.8539813e-01 -7.5921828e-01
#  -7.3303831e-01 -7.0685840e-01 -6.8067831e-01 -6.5449846e-01
#  -6.2831843e-01 -6.0213858e-01 -5.7595861e-01 -5.4977864e-01
#  -5.2359861e-01 -4.9741876e-01 -4.7123879e-01 -4.4505894e-01
#  -4.1887897e-01 -3.9269906e-01 -3.6651915e-01 -3.4033924e-01
#  -3.1415915e-01 -2.8797925e-01 -2.6179934e-01 -2.3561937e-01
#  -2.0943934e-01 -1.8325943e-01 -1.5707952e-01 -1.3089955e-01
#  -1.0471964e-01 -7.8539729e-02 -5.2359819e-02 -2.6179850e-02
#   5.9604645e-08  2.6180089e-02  5.2359998e-02  7.8539968e-02
#   1.0471988e-01  1.3089979e-01  1.5707976e-01  1.8325967e-01
#   2.0943964e-01  2.3561960e-01  2.6179957e-01  2.8797948e-01
#   3.1415939e-01  3.4033930e-01  3.6651927e-01  3.9269924e-01
#   4.1887915e-01  4.4505912e-01  4.7123897e-01  4.9741894e-01
#   5.2359897e-01  5.4977882e-01  5.7595885e-01  6.0213882e-01
#   6.2831867e-01  6.5449870e-01  6.8067849e-01  7.0685852e-01
#   7.3303843e-01  7.5921839e-01  7.8539836e-01  8.1157833e-01
#   8.3775818e-01  8.6393815e-01  8.9011800e-01  9.1629803e-01
#   9.4247806e-01  9.6865791e-01  9.9483788e-01  1.0210178e+00
#   1.0471977e+00  1.0733776e+00  1.0995576e+00  1.1257375e+00
#   1.1519176e+00  1.1780974e+00  1.2042774e+00  1.2304573e+00
#   1.2566372e+00  1.2828171e+00  1.3089972e+00  1.3351771e+00
#   1.3613571e+00  1.3875370e+00  1.4137169e+00  1.4398968e+00
#   1.4660767e+00  1.4922566e+00  1.5184368e+00  1.5446166e+00], recompile_flag=True),
#                   'auto_regularize_flag': Param(val=True, recompile_flag=False),
#                   'delta_det_channel': Param(val=1.0, recompile_flag=True),
#                   'delta_det_row': Param(val=1.0, recompile_flag=True),
#                   'delta_voxel': Param(val=1.0, recompile_flag=True),
#                   'det_channel_offset': Param(val=0.0, recompile_flag=True),
#                   'det_row_offset': Param(val=0.0, recompile_flag=True),
#                   'file_format': Param(val=1.0, recompile_flag=False),
#                   'geometry_type': Param(val=<class 'mbirjax.parallel_beam.ParallelBeamModel'>, recompile_flag=False),
#                   'granularity': Param(val=[1, 2, 4, 8, 16, 32, 64, 128, 256], recompile_flag=False),
#                   'p': Param(val=2.0, recompile_flag=False),
#                   'partition_sequence': Param(val=[0, 2, 4, 6, 7], recompile_flag=False),
#                   'positivity_flag': Param(val=False, recompile_flag=False),
#                   'q': Param(val=1.2, recompile_flag=False),
#                   'qggmrf_nbr_wts': Param(val=[1.0, 1.0, 1.0], recompile_flag=False),
#                   'recon_shape': Param(val=(100, 100, 80), recompile_flag=True),
#                   'sharpness': Param(val=-1.5, recompile_flag=False),
#                   'sigma_prox': Param(val=0.012591972015798092, recompile_flag=False),
#                   'sigma_x': Param(val=0.012591972015798092, recompile_flag=False),
#                   'sigma_y': Param(val=0.5977396965026855, recompile_flag=False),
#                   'sinogram_shape': Param(val=(120, 80, 100), recompile_flag=True),
#                   'snr_db': Param(val=30.0, recompile_flag=False),
#                   'use_gpu': Param(val=automatic, recompile_flag=True),
#                   'verbose': Param(val=1, recompile_flag=False),
#                   'view_params_name': Param(val=angles, recompile_flag=True)},
#  'notes': 'Reconstruction completed: 2025-06-26 14:42:40.795170\n\n',
#  'recon_log': 'GPU used for: full\n'
#               'Estimated GPU memory required = 1.281 GB, available = 91.115 '
#               'GB\n'
#               'Estimated CPU memory required = 0.013 GB, available = 1463.766 '
#               'GB\n'
#               'Starting direct recon for initial reconstruction\n'
#               'Initializing error sinogram\n'
#               'Computing Hessian diagonal\n'
#               'Starting VCD iterations\n'
#               '\n'
#               'After iteration 0 of a max of 15: Pct change=6.8342, Forward '
#               'loss=6.0597\n'
#               'Relative step size (alpha)=0.18, Error sino RMSE=3.6221\n'
#               'Number subsets = 1\n'
#               '\n'
#               'After iteration 1 of a max of 15: Pct change=9.5596, Forward '
#               'loss=5.8612\n'
#               'Relative step size (alpha)=0.56, Error sino RMSE=3.5035\n'
#               'Number subsets = 4\n'
#               '\n'
#               'After iteration 2 of a max of 15: Pct change=9.3781, Forward '
#               'loss=5.7834\n'
#               'Relative step size (alpha)=1.47, Error sino RMSE=3.4570\n'
#               'Number subsets = 16\n'
#               '\n'
#               'After iteration 3 of a max of 15: Pct change=4.1690, Forward '
#               'loss=5.7644\n'
#               'Relative step size (alpha)=1.50, Error sino RMSE=3.4456\n'
#               'Number subsets = 64\n'
#               '\n'
#               'After iteration 4 of a max of 15: Pct change=2.0243, Forward '
#               'loss=5.7576\n'
#               'Relative step size (alpha)=1.50, Error sino RMSE=3.4415\n'
#               'Number subsets = 128\n'
#               '\n'
#               'After iteration 5 of a max of 15: Pct change=1.1462, Forward '
#               'loss=5.7539\n'
#               'Relative step size (alpha)=1.50, Error sino RMSE=3.4393\n'
#               'Number subsets = 128\n'
#               '\n'
#               'After iteration 6 of a max of 15: Pct change=0.7416, Forward '
#               'loss=5.7519\n'
#               'Relative step size (alpha)=1.50, Error sino RMSE=3.4382\n'
#               'Number subsets = 128\n'
#               '\n'
#               'After iteration 7 of a max of 15: Pct change=0.5177, Forward '
#               'loss=5.7505\n'
#               'Relative step size (alpha)=1.50, Error sino RMSE=3.4373\n'
#               'Number subsets = 128\n'
#               '\n'
#               'After iteration 8 of a max of 15: Pct change=0.3786, Forward '
#               'loss=5.7496\n'
#               'Relative step size (alpha)=1.50, Error sino RMSE=3.4367\n'
#               'Number subsets = 128\n'
#               '\n'
#               'After iteration 9 of a max of 15: Pct change=0.2872, Forward '
#               'loss=5.7489\n'
#               'Relative step size (alpha)=1.50, Error sino RMSE=3.4363\n'
#               'Number subsets = 128\n'
#               '\n'
#               'After iteration 10 of a max of 15: Pct change=0.2261, Forward '
#               'loss=5.7483\n'
#               'Relative step size (alpha)=1.50, Error sino RMSE=3.4360\n'
#               'Number subsets = 128\n'
#               '\n'
#               'After iteration 11 of a max of 15: Pct change=0.1815, Forward '
#               'loss=5.7479\n'
#               'Relative step size (alpha)=1.50, Error sino RMSE=3.4358\n'
#               'Number subsets = 128\n'
#               'Change threshold stopping condition reached\n'
#               'Logs written to '
#               '/home/zhengtan/repos/scico/examples/mbirjax_scripts/logs/recon.log\n',
#  'recon_params': {'alpha_values': [0.17534880340099335, 0.5600396394729614,
#                                    1.4698677062988281, 1.5, 1.4996058940887451,
#                                    1.5, 1.5, 1.5, 1.5, 1.5, 1.5, 1.5],
#                   'fm_rmse': [6.059716701507568, 5.861193656921387,
#                               5.78340482711792, 5.764382362365723,
#                               5.757559776306152, 5.753905296325684,
#                               5.751924991607666, 5.75052547454834,
#                               5.74957275390625, 5.7488555908203125,
#                               5.748330593109131, 5.747905254364014],
#                   'granularity': [1, 2, 4, 8, 16, 32, 64, 128, 256],
#                   'num_iterations': 12,
#                   'partition_sequence': [0, 2, 4, 6, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#                                          7, 7],
#                   'prior_loss': [0],
#                   'regularization_params': {'sigma_prox': 0.012591972015798092,
#                                             'sigma_x': 0.012591972015798092,
#                                             'sigma_y': 0.5977396965026855},
#                   'stop_threshold_change_pct': [6.834200024604797,
#                                                 9.55960527062416,
#                                                 9.37812477350235,
#                                                 4.168964922428131,
#                                                 2.0242752507328987,
#                                                 1.1461928486824036,
#                                                 0.7416053675115108,
#                                                 0.5176734179258347,
#                                                 0.3786018816754222,
#                                                 0.28722535353153944,
#                                                 0.22611799649894238,
#                                                 0.18151988042518497]}}

# %%
# Display results
title = 'Recon with sharpness = {:.1f}: Phantom (left) vs VCD Recon (right)'.format(sharpness)
title += '\nAdjust intensity range to [0, 1] to see reduced internal artifacts from projection outside detector.'
title += '\nOuter ring is still evident in intensity range [1, 2], and edges are blurry.'

save_path = './results/recon_smooth.png'
mbirjax.slice_viewer(phantom, recon_smooth, title=title, vmin=0.0, vmax=2.0, save=True, save_path=save_path)

# %% [markdown]
# **Padded recon VCD reconstruction**
#
# Alternatively, we can pad the recon to allow for a partial reconstruction of the pixels that project outside the detector in some views.  This reduces the artifacts without blurring edges and greatly reduces the outer ring seen in the non-padded recon.
#
# Note that the enlarged recon doesn't have to match the phantom size.  Increasing the recon size won't allow us to fully reconstruct the pixels that sometimes project outside the detector.  However, it will provide
# room for those partial projections to be absorbed into partial projected pixels, which allows for better reconstruction of the pixels with full projections.

# %%
# Increase the recon size.  In this case, we increase just the columns to
# approximate the phantom shape.  Note that it doesn't have to be an exact match.
recon_row_scale = 1.0
recon_col_scale = 1.5
ct_model_for_recon.scale_recon_shape(row_scale=recon_row_scale, col_scale=recon_col_scale)

# Reset the default sharpness
sharpness = 1.0
ct_model_for_recon.set_params(sharpness=sharpness)

print('\nStarting enlarged recon - will have reduced artifacts, sharper edges, some extra pixel estimation.\n')
recon_enlarged, recon_params_enlarged = ct_model_for_recon.recon(sinogram, weights=weights)

# Print out parameters used in recon
if isinstance(recon_params_enlarged, dict):
    pprint.pprint(recon_params_enlarged, compact=True)
else:
    pprint.pprint(recon_params_enlarged._asdict(), compact=True)
# Out:
# GPU used for: full
# Estimated GPU memory required = 1.290 GB, available = 91.115 GB
# Estimated CPU memory required = 0.016 GB, available = 1464.062 GB
# Starting direct recon for initial reconstruction
# Starting enlarged recon - will have reduced artifacts, sharper edges, some extra pixel estimation.
# Initializing error sinogram
# Computing Hessian diagonal
# Starting VCD iterations
#
# After iteration 0 of a max of 15: Pct change=17.3300, Forward loss=3.9277
# Relative step size (alpha)=0.02, Error sino RMSE=2.3477
# Number subsets = 1
#
# After iteration 1 of a max of 15: Pct change=27.6356, Forward loss=2.0536
# Relative step size (alpha)=0.07, Error sino RMSE=1.2275
# Number subsets = 4
#
# After iteration 2 of a max of 15: Pct change=23.2523, Forward loss=1.0957
# Relative step size (alpha)=0.28, Error sino RMSE=0.6549
# Number subsets = 16
#
# After iteration 3 of a max of 15: Pct change=25.0472, Forward loss=0.4843
# Relative step size (alpha)=1.04, Error sino RMSE=0.2895
# Number subsets = 64
#
# After iteration 4 of a max of 15: Pct change=12.3870, Forward loss=0.3212
# Relative step size (alpha)=1.15, Error sino RMSE=0.1920
# Number subsets = 128
#
# After iteration 5 of a max of 15: Pct change=7.1385, Forward loss=0.2656
# Relative step size (alpha)=1.14, Error sino RMSE=0.1588
# Number subsets = 128
#
# After iteration 6 of a max of 15: Pct change=4.9560, Forward loss=0.2398
# Relative step size (alpha)=1.14, Error sino RMSE=0.1433
# Number subsets = 128
#
# After iteration 7 of a max of 15: Pct change=3.5492, Forward loss=0.2255
# Relative step size (alpha)=1.14, Error sino RMSE=0.1348
# Number subsets = 128
#
# After iteration 8 of a max of 15: Pct change=2.7208, Forward loss=0.2161
# Relative step size (alpha)=1.15, Error sino RMSE=0.1292
# Number subsets = 128
#
# After iteration 9 of a max of 15: Pct change=2.0935, Forward loss=0.2093
# Relative step size (alpha)=1.16, Error sino RMSE=0.1251
# Number subsets = 128
#
# After iteration 10 of a max of 15: Pct change=1.6289, Forward loss=0.2043
# Relative step size (alpha)=1.16, Error sino RMSE=0.1221
# Number subsets = 128
#
# After iteration 11 of a max of 15: Pct change=1.2821, Forward loss=0.2006
# Relative step size (alpha)=1.16, Error sino RMSE=0.1199
# Number subsets = 128
#
# After iteration 12 of a max of 15: Pct change=1.0512, Forward loss=0.1976
# Relative step size (alpha)=1.17, Error sino RMSE=0.1181
# Number subsets = 128
#
# After iteration 13 of a max of 15: Pct change=0.8976, Forward loss=0.1951
# Relative step size (alpha)=1.17, Error sino RMSE=0.1166
# Number subsets = 128
#
# After iteration 14 of a max of 15: Pct change=0.7819, Forward loss=0.1931
# Relative step size (alpha)=1.19, Error sino RMSE=0.1154
# Number subsets = 128
# Logs written to /home/zhengtan/repos/scico/examples/mbirjax_scripts/logs/recon.log
# {'model_params': {'T': Param(val=1.0, recompile_flag=False),
#                   'angles': Param(val=[-1.5707964e+00 -1.5446163e+00 -1.5184366e+00 -1.4922565e+00
#  -1.4660765e+00 -1.4398967e+00 -1.4137167e+00 -1.3875369e+00
#  -1.3613569e+00 -1.3351769e+00 -1.3089970e+00 -1.2828170e+00
#  -1.2566370e+00 -1.2304572e+00 -1.2042772e+00 -1.1780972e+00
#  -1.1519173e+00 -1.1257374e+00 -1.0995575e+00 -1.0733775e+00
#  -1.0471975e+00 -1.0210177e+00 -9.9483764e-01 -9.6865779e-01
#  -9.4247770e-01 -9.1629779e-01 -8.9011782e-01 -8.6393797e-01
#  -8.3775795e-01 -8.1157815e-01 -7.8539813e-01 -7.5921828e-01
#  -7.3303831e-01 -7.0685840e-01 -6.8067831e-01 -6.5449846e-01
#  -6.2831843e-01 -6.0213858e-01 -5.7595861e-01 -5.4977864e-01
#  -5.2359861e-01 -4.9741876e-01 -4.7123879e-01 -4.4505894e-01
#  -4.1887897e-01 -3.9269906e-01 -3.6651915e-01 -3.4033924e-01
#  -3.1415915e-01 -2.8797925e-01 -2.6179934e-01 -2.3561937e-01
#  -2.0943934e-01 -1.8325943e-01 -1.5707952e-01 -1.3089955e-01
#  -1.0471964e-01 -7.8539729e-02 -5.2359819e-02 -2.6179850e-02
#   5.9604645e-08  2.6180089e-02  5.2359998e-02  7.8539968e-02
#   1.0471988e-01  1.3089979e-01  1.5707976e-01  1.8325967e-01
#   2.0943964e-01  2.3561960e-01  2.6179957e-01  2.8797948e-01
#   3.1415939e-01  3.4033930e-01  3.6651927e-01  3.9269924e-01
#   4.1887915e-01  4.4505912e-01  4.7123897e-01  4.9741894e-01
#   5.2359897e-01  5.4977882e-01  5.7595885e-01  6.0213882e-01
#   6.2831867e-01  6.5449870e-01  6.8067849e-01  7.0685852e-01
#   7.3303843e-01  7.5921839e-01  7.8539836e-01  8.1157833e-01
#   8.3775818e-01  8.6393815e-01  8.9011800e-01  9.1629803e-01
#   9.4247806e-01  9.6865791e-01  9.9483788e-01  1.0210178e+00
#   1.0471977e+00  1.0733776e+00  1.0995576e+00  1.1257375e+00
#   1.1519176e+00  1.1780974e+00  1.2042774e+00  1.2304573e+00
#   1.2566372e+00  1.2828171e+00  1.3089972e+00  1.3351771e+00
#   1.3613571e+00  1.3875370e+00  1.4137169e+00  1.4398968e+00
#   1.4660767e+00  1.4922566e+00  1.5184368e+00  1.5446166e+00], recompile_flag=True),
#                   'auto_regularize_flag': Param(val=True, recompile_flag=False),
#                   'delta_det_channel': Param(val=1.0, recompile_flag=True),
#                   'delta_det_row': Param(val=1.0, recompile_flag=True),
#                   'delta_voxel': Param(val=1.0, recompile_flag=True),
#                   'det_channel_offset': Param(val=0.0, recompile_flag=True),
#                   'det_row_offset': Param(val=0.0, recompile_flag=True),
#                   'file_format': Param(val=1.0, recompile_flag=False),
#                   'geometry_type': Param(val=<class 'mbirjax.parallel_beam.ParallelBeamModel'>, recompile_flag=False),
#                   'granularity': Param(val=[1, 2, 4, 8, 16, 32, 64, 128, 256], recompile_flag=False),
#                   'p': Param(val=2.0, recompile_flag=False),
#                   'partition_sequence': Param(val=[0, 2, 4, 6, 7], recompile_flag=False),
#                   'positivity_flag': Param(val=False, recompile_flag=False),
#                   'q': Param(val=1.2, recompile_flag=False),
#                   'qggmrf_nbr_wts': Param(val=[1.0, 1.0, 1.0], recompile_flag=False),
#                   'recon_shape': Param(val=(100, 150, 80), recompile_flag=True),
#                   'sharpness': Param(val=1.0, recompile_flag=False),
#                   'sigma_prox': Param(val=0.071230947971344, recompile_flag=False),
#                   'sigma_x': Param(val=0.071230947971344, recompile_flag=False),
#                   'sigma_y': Param(val=0.5977396965026855, recompile_flag=False),
#                   'sinogram_shape': Param(val=(120, 80, 100), recompile_flag=True),
#                   'snr_db': Param(val=30.0, recompile_flag=False),
#                   'use_gpu': Param(val=automatic, recompile_flag=True),
#                   'verbose': Param(val=1, recompile_flag=False),
#                   'view_params_name': Param(val=angles, recompile_flag=True)},
#  'notes': 'Reconstruction completed: 2025-06-26 14:42:54.773714\n\n',
#  'recon_log': 'GPU used for: full\n'
#               'Estimated GPU memory required = 1.290 GB, available = 91.115 '
#               'GB\n'
#               'Estimated CPU memory required = 0.016 GB, available = 1464.062 '
#               'GB\n'
#               'Starting direct recon for initial reconstruction\n'
#               'Initializing error sinogram\n'
#               'Computing Hessian diagonal\n'
#               'Starting VCD iterations\n'
#               '\n'
#               'After iteration 0 of a max of 15: Pct change=17.3300, Forward '
#               'loss=3.9277\n'
#               'Relative step size (alpha)=0.02, Error sino RMSE=2.3477\n'
#               'Number subsets = 1\n'
#               '\n'
#               'After iteration 1 of a max of 15: Pct change=27.6356, Forward '
#               'loss=2.0536\n'
#               'Relative step size (alpha)=0.07, Error sino RMSE=1.2275\n'
#               'Number subsets = 4\n'
#               '\n'
#               'After iteration 2 of a max of 15: Pct change=23.2523, Forward '
#               'loss=1.0957\n'
#               'Relative step size (alpha)=0.28, Error sino RMSE=0.6549\n'
#               'Number subsets = 16\n'
#               '\n'
#               'After iteration 3 of a max of 15: Pct change=25.0472, Forward '
#               'loss=0.4843\n'
#               'Relative step size (alpha)=1.04, Error sino RMSE=0.2895\n'
#               'Number subsets = 64\n'
#               '\n'
#               'After iteration 4 of a max of 15: Pct change=12.3870, Forward '
#               'loss=0.3212\n'
#               'Relative step size (alpha)=1.15, Error sino RMSE=0.1920\n'
#               'Number subsets = 128\n'
#               '\n'
#               'After iteration 5 of a max of 15: Pct change=7.1385, Forward '
#               'loss=0.2656\n'
#               'Relative step size (alpha)=1.14, Error sino RMSE=0.1588\n'
#               'Number subsets = 128\n'
#               '\n'
#               'After iteration 6 of a max of 15: Pct change=4.9560, Forward '
#               'loss=0.2398\n'
#               'Relative step size (alpha)=1.14, Error sino RMSE=0.1433\n'
#               'Number subsets = 128\n'
#               '\n'
#               'After iteration 7 of a max of 15: Pct change=3.5492, Forward '
#               'loss=0.2255\n'
#               'Relative step size (alpha)=1.14, Error sino RMSE=0.1348\n'
#               'Number subsets = 128\n'
#               '\n'
#               'After iteration 8 of a max of 15: Pct change=2.7208, Forward '
#               'loss=0.2161\n'
#               'Relative step size (alpha)=1.15, Error sino RMSE=0.1292\n'
#               'Number subsets = 128\n'
#               '\n'
#               'After iteration 9 of a max of 15: Pct change=2.0935, Forward '
#               'loss=0.2093\n'
#               'Relative step size (alpha)=1.16, Error sino RMSE=0.1251\n'
#               'Number subsets = 128\n'
#               '\n'
#               'After iteration 10 of a max of 15: Pct change=1.6289, Forward '
#               'loss=0.2043\n'
#               'Relative step size (alpha)=1.16, Error sino RMSE=0.1221\n'
#               'Number subsets = 128\n'
#               '\n'
#               'After iteration 11 of a max of 15: Pct change=1.2821, Forward '
#               'loss=0.2006\n'
#               'Relative step size (alpha)=1.16, Error sino RMSE=0.1199\n'
#               'Number subsets = 128\n'
#               '\n'
#               'After iteration 12 of a max of 15: Pct change=1.0512, Forward '
#               'loss=0.1976\n'
#               'Relative step size (alpha)=1.17, Error sino RMSE=0.1181\n'
#               'Number subsets = 128\n'
#               '\n'
#               'After iteration 13 of a max of 15: Pct change=0.8976, Forward '
#               'loss=0.1951\n'
#               'Relative step size (alpha)=1.17, Error sino RMSE=0.1166\n'
#               'Number subsets = 128\n'
#               '\n'
#               'After iteration 14 of a max of 15: Pct change=0.7819, Forward '
#               'loss=0.1931\n'
#               'Relative step size (alpha)=1.19, Error sino RMSE=0.1154\n'
#               'Number subsets = 128\n'
#               'Logs written to '
#               '/home/zhengtan/repos/scico/examples/mbirjax_scripts/logs/recon.log\n',
#  'recon_params': {'alpha_values': [0.019008763134479523, 0.07137793302536011,
#                                    0.28181999921798706, 1.0376758575439453,
#                                    1.1531788110733032, 1.1407470703125,
#                                    1.1427371501922607, 1.1355886459350586,
#                                    1.1500442028045654, 1.1581640243530273,
#                                    1.1604831218719482, 1.1569124460220337,
#                                    1.171594500541687, 1.1725449562072754,
#                                    1.1871938705444336],
#                   'fm_rmse': [3.927677869796753, 2.0535662174224854,
#                               1.095678687095642, 0.4842871427536011,
#                               0.3211982548236847, 0.26562315225601196,
#                               0.23976100981235504, 0.2255411148071289,
#                               0.2160806655883789, 0.20925872027873993,
#                               0.20429204404354095, 0.2005501687526703,
#                               0.1975870579481125, 0.19511470198631287,
#                               0.193055659532547],
#                   'granularity': [1, 2, 4, 8, 16, 32, 64, 128, 256],
#                   'num_iterations': 15,
#                   'partition_sequence': [0, 2, 4, 6, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#                                          7, 7],
#                   'prior_loss': [0],
#                   'regularization_params': {'sigma_prox': 0.071230947971344,
#                                             'sigma_x': 0.071230947971344,
#                                             'sigma_y': 0.5977396965026855},
#                   'stop_threshold_change_pct': [17.32996255159378,
#                                                 27.635592222213745,
#                                                 23.252305388450623,
#                                                 25.047191977500916,
#                                                 12.386994063854218,
#                                                 7.138466835021973,
#                                                 4.955999925732613,
#                                                 3.549184650182724,
#                                                 2.720830589532852,
#                                                 2.0935269072651863,
#                                                 1.6289236024022102,
#                                                 1.2821297161281109,
#                                                 1.0512110777199268,
#                                                 0.8976240642368793,
#                                                 0.7818577811121941]}}

# %% [markdown]
# **Display the result using the enlarged reconstruction.**

# %%
title = 'Padded recon with sharpness = {:.1f}: Phantom (left) vs VCD Recon (right)'.format(sharpness)
title += '\nPadding the recon reduces the internal artifacts even with default sharpness.'
title += '\nEdges are sharp, outer ring is mostly gone, and the partially projected pixels are partially recovered.'

save_path = './results/recon_enlarged.png'
mbirjax.slice_viewer(phantom, recon_enlarged, title=title, vmin=0.0, vmax=2.0, save=True, save_path=save_path)

# %% [markdown]
# **Next:** Try changing some of the parameters and re-running or try [some of the other demos](https://mbirjax.readthedocs.io/en/latest/demos_and_faqs.html).
